# %%
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt

# %%
shapec = gpd.read_file('2011_Dist.shp')
shapec
shapec.sort_values('censuscode')
# Out:
#                    DISTRICT                     ST_NM  ST_CEN_CD  DT_CEN_CD  \
# 135      Data Not Available           Jammu & Kashmir         99         99
# 326                 Kupwara           Jammu & Kashmir          1          1
# 31                   Badgam           Jammu & Kashmir          1          2
# 338            Leh (ladakh)           Jammu & Kashmir          1          3
# 283                  Kargil           Jammu & Kashmir          1          4
# ..                      ...                       ...        ...        ...
# 353                    Mahe                Puducherry         34          3
# 633                Karaikal                Puducherry         34          4
# 637                 Nicobar  Andaman & Nicobar Island         35          1
# 639  North & Middle Andaman  Andaman & Nicobar Island         35          2
# 638           South Andaman  Andaman & Nicobar Island         35          3
#
# ...

# %%
Alld=pd.read_csv('clssnumpy.csv')
Alld
# Out:
#      class  State  censuscode  PersonsPopulation  MalesPopulation  \
# 0        1      9         158            3405559          1752542
# 1        1     18         306            1924110           983904
# 2        1     24         485            2127086          1068651
# 3        1     23         464            1025048           515023
# 4        1     10         219            3951862          2022821
# ..     ...    ...         ...                ...              ...
# 635      4      9         138            3443689          1825743
# 636      4     33         608            3482056          1781571
# 637      4     33         625            1942288           967709
# 638      4     33         627            1750176           865021
# 639      4      1          21            1529958           813821
#
#      FemalesPopulation  PersonsMain workers  MalesMain workers  \
# 0              1653017               644869             520983
# ...

# %%
for_plot = shapec.merge(Alld, left_on = 'censuscode', right_on = 'censuscode');
for_plot.sort_values('censuscode')
# Out:
#                    DISTRICT                     ST_NM  ST_CEN_CD  DT_CEN_CD  \
# 325                 Kupwara           Jammu & Kashmir          1          1
# 31                   Badgam           Jammu & Kashmir          1          2
# 337            Leh (ladakh)           Jammu & Kashmir          1          3
# 282                  Kargil           Jammu & Kashmir          1          4
# 449                   Punch           Jammu & Kashmir          1          5
# ..                      ...                       ...        ...        ...
# 352                    Mahe                Puducherry         34          3
# 632                Karaikal                Puducherry         34          4
# 636                 Nicobar  Andaman & Nicobar Island         35          1
# 638  North & Middle Andaman  Andaman & Nicobar Island         35          2
# 637           South Andaman  Andaman & Nicobar Island         35          3
#
# ...

# %%
ax=for_plot.plot(column='censuscode', cmap ='PuBuGn', figsize=(16,10),edgecolor='black',legend ='True');

# %%
for_plot.plot(column='urban rural ratio', cmap ='PuBuGn', figsize=(16,10),scheme='User_Defined',legend =True,classification_kwds=dict(bins=[0.10,0.3,1.0,2000]));
plt.title('Classification of districts,2011', fontsize=18)
for_plot[for_plot.class.isna()].plot(color='lightgrey', hatch='///', ax=ax)
plt.title('Classification of districts,2011', fontsize=18)
# Out:
#   File "<ipython-input-7-71c0825268d7>", line 1
#     for_plot.plot(column='urban rural ratio', cmap ='PuBuGn', figsize=(16,10),,scheme='User_Defined',legend =True,classification_kwds=dict(bins=[0.10,0.3,1.0,2000]));
#                                                                               ^
# SyntaxError: invalid syntax
